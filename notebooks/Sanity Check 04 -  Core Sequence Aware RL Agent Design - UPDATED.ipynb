# %% [markdown]
# #  Core Sequence-Aware Agent Design v2
#
# This experiment explores a transformer-based recurrent PPO agent for financial trading. The environment is sequence-aware and includes both regime-based augmentation and per-episode reward normalization. The agent is evaluated across top 2 stocks in each sector using structured episode sequences to assess learning generalization.
#
# ---
#
# ##  Experiment Configuration
#
# | Parameter               | Value                         |
# |-------------------------|-------------------------------|
# | Agent                   | Recurrent PPO + Transformer   |
# | Env Wrapper             | RegimeAugmentingWrapper + PerEpisodeRewardNormalizer |
# | Episode Length          | 100                           |
# | Episodes                | 20                            |
# | Eval Episodes           | 3 per iteration               |
# | Steps per Update        | 800                           |
# | Batch Size              | 100                           |
# | Total Timesteps         | 20,000                        |
# | Learning Rate           | 0.0003                        |
# | Entropy Coefficient     | 0.005                         |
# | Value Function Coeff    | 0.5                           |
# | Max Gradient Norm       | 0.5                           |
# | Normalize Advantage     | True                          |
# | Optimizer               | Adam                          |
# | Transformer d_model     | 64                            |
# | Heads                  | 4                             |
# | Layers                 | 2                             |
#
# ---
#
# ## Environment Setup
#
# - **Train Set:** 2023-01-01 → 2023-07-01
# - **Test Set:** 2023-07-01 → 2024-01-01
# - **Assets:** Top 2 stocks by sector
# - **Sequence Split:** 80% train / 20% eval sequences
#
# ---
#
# ##  Agent Architecture
#
# - **Feature Extractor:** Transformer encoder with causal mask and learnable positional encoding.
# - **Policy Class:** Custom `TransformerPolicy` extending `RecurrentActorCriticPolicy`.
# - **Reward Normalization:** Online normalization within episodes.
# - **Regime Augmentation:** Appends one-hot encoded market regime to each timestep.
#
# ---
#
# ## Training Summary (Selected Stats)
#
# | Timesteps | Ep Rew Mean | Explained Variance | Value Loss | Policy Grad Loss |
# |-----------|-------------|--------------------|------------|------------------|
# |  8000     | 3.21        | 0.15               | 4.68       | -0.00277         |
# | 14400     | 2.90        | 0.645              | 1.71       |  0.00163         |
# | 20000     | **3.79**    | **0.751**          | 1.59       | -0.00012         |
#
# ---
#
# ## Evaluation Snapshots
#
# | Timestep | Mean Reward | Std Dev | Eval Length |
# |----------|-------------|---------|-------------|
# | 5000     | -8.17       | ±8.72   | 102         |
# | 10000    | -4.43       | ±7.59   | 102         |
# | 15000    | -6.17       | ±4.92   | 102         |
# | 20000    | **0.24**    | ±2.86   | 102         |
#
# ---
#
# ## Statistical Significance
#
# ### Paired t-test and Mann-Whitney U-test
#
# | Metric       | t-test p-value | Mann-Whitney p-value |
# |--------------|----------------|-----------------------|
# | `total_reward` | 0.0300         | 0.0075                |
# | `calmar`       | 0.0132         | 0.0075                |
#
# ✅ Both `total_reward` and `calmar ratio` show **statistically significant** improvements compared to the baseline.
# Especially, Calmar implies **more stable and risk-adjusted returns**.
#
# > Note: `sharpe`, `sortino`, and `final_wealth` were skipped due to empty values in the evaluation logs. Ensure metrics are logged and valid across all test episodes to include them.
#
# ---
#
# ## Next Steps
#
# 1. **Fix missing metrics** (`sharpe`, `sortino`, etc.) in the logging pipeline.
# 2. **Plot distribution comparisons** (boxplots, histograms) for rewards and risk-adjusted returns.
# 3. **Run ablation**:
#    - Without regime augmentation
#    - Without reward normalization
#    - With simpler agents (e.g., MLP or LSTM)
# 4. **Test in unseen market conditions** or during volatility spikes to check robustness.
#
# ---
#
# _Logged using `ExperimentTracker` — Run Hash: `${experiment_tracker.run_hash}`_

# %%
# SETUP ===================================
import jupyter
import warnings

from src.utils.system import boot, Notify

boot()
warnings.filterwarnings("ignore")



# PACKAGES ================================
import os
import torch
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import torch.nn as nn
import gymnasium as gym
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.preprocessing import  RobustScaler

# FRAMEWORK STUFF =========================
from src.defaults import TOP2_STOCK_BY_SECTOR, FEATURE_COLS,EPISODE_LENGTH
from src.data.feature_pipeline import load_base_dataframe
from src.experiments.experiment_tracker import ExperimentTracker
from src.env.base_timeseries_trading_env import BaseSequenceAwareTradingEnv,SequenceAwareAlphaTradingEnv,SequenceAwareBaselineTradingAgent,SequenceAwareCalmarTradingEnv,SequenceAwareCumulativeTradingEnv,SequenceAwareDrawdownTradingEnv,SequenceAwareHybridTradingEnv,SequenceAwareHybridTradingEnv,SequenceAwareSharpeTradingEnv,SequenceAwareSortinoTradingEnv

from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy

# %%
# ========== CONFIG ==========
EXPERIENCE_NAME = "core_sequence_aware_agent_design_v2"
RESULTS_PATH = f"data/experiments/{EXPERIENCE_NAME}_barebones_results.csv"
N_EPISODES = 20
N_SEEDS = 3
N_EVAL_EPISODES = 3

WINDOW_LENGTH = 10  
TOTAL_TIMESTEPS = EPISODE_LENGTH * 150
N_STEPS = EPISODE_LENGTH * 2

TRANSACTION_COST = 0

CONFIG = {
    "batch_size": EPISODE_LENGTH,
    "n_steps": 800,
    "total_timesteps": TOTAL_TIMESTEPS,
    "project_name":EXPERIENCE_NAME
}




# Load data ==================================
ohlcv_df = load_base_dataframe()

# Experiment tracker ========================= 
experiment_tracker = ExperimentTracker(EXPERIENCE_NAME)
experiment_tracker.set_hash(CONFIG)

# Files ======================================
checkpoint_path = "data/checkpoint" 
checkpoint_name = experiment_tracker.run_hash
checkpoint_preffix = f"{checkpoint_name}--checkpoint"
checkpoint_best_model=f"{checkpoint_path}/{checkpoint_name}--best_model"
log_path="data/logs"
save_path= f"{checkpoint_path}/{checkpoint_name}--final"
print(save_path)
# Out:
# data/checkpoint/-8377624099423380081--final

# %%
EPISODE_LENGTH = 100
MAX_LENGTH = 200
SAVE_FREQ=10000
EVAL_FREQ=5000
TOTAL_TIMESTEPS=200000
#TOTAL_TIMESTEPS=1000
EPISODES_PER_UPDATE = 8          # ~how many episodes before PPO updates
EPISODES_PER_BATCH = 1           # number of full episodes per batch

# === Auto-derive PPO settings ===
N_STEPS = EPISODE_LENGTH * EPISODES_PER_UPDATE
BATCH_SIZE = EPISODE_LENGTH * EPISODES_PER_BATCH

ENV_CLASS = SequenceAwareCumulativeTradingEnv

n = Notify(experiment_tracker.project)
n.info('START')
print(N_STEPS,BATCH_SIZE)
# Out:
# 800 100

# %%
import torch
import torch.nn as nn
import numpy as np
import gymnasium as gym
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from sb3_contrib.common.recurrent.policies import RecurrentActorCriticPolicy

# Causal Mask Function ============================
def generate_causal_mask(seq_len):
    return torch.triu(torch.ones((seq_len, seq_len), dtype=torch.bool), diagonal=1)

# Transformer Feature Extractor ===================
class TransformerFeatureExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, d_model=64, n_heads=4, n_layers=2, max_len=MAX_LENGTH):
        super().__init__(observation_space, features_dim=d_model)
        self.d_model = d_model
        input_dim = observation_space.shape[-1]

        self.input_proj = nn.Linear(input_dim, d_model)
        self.positional_encoding = nn.Parameter(torch.randn(max_len, d_model))

        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, batch_first=True)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

    def forward_v1(self, obs):
        # obs shape: (batch, seq_len, input_dim)
        x = self.input_proj(obs)
        seq_len = x.size(1)
        x = x + self.positional_encoding[:seq_len]
        causal_mask = generate_causal_mask(seq_len).to(x.device)
        x = self.transformer(x, mask=causal_mask)
        return x[:, -1]  # return the last token output
    
    def forward(self, obs):
        # obs shape: (batch, seq_len, input_dim)
        #print(">>> [Transformer] Input shape:", obs.shape)

        x = self.input_proj(obs)
        seq_len = x.size(1)
        x = x + self.positional_encoding[:seq_len]

        causal_mask = generate_causal_mask(seq_len).to(x.device)
        x = self.transformer(x, mask=causal_mask)

        pooled_output = x[:, -1]
        #print(">>> [Transformer] Pooled output mean/std:", pooled_output.mean().item(), pooled_output.std().item())

        return pooled_output

# Transformer Policy ===================================
class TransformerPolicy(RecurrentActorCriticPolicy):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs,
                         features_extractor_class=TransformerFeatureExtractor,
                         features_extractor_kwargs=dict(
                             d_model=64, n_heads=4, n_layers=2, max_len=32
                         ))
        #self._build(self.lr_schedule)

# Regime Augmentation Wrapper ===========================
class RegimeAugmentingWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.regime_dim = 3  # One-hot: bull, bear, sideways
        obs_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(obs_shape[0], obs_shape[1] + self.regime_dim),
            dtype=np.float32
        )

    def observation(self, obs):
        regime = self.env.get_current_regime()  # 0,1,2 -> bull,bear,sideways
        one_hot = np.zeros(self.regime_dim)
        one_hot[regime] = 1.0
        one_hot = np.repeat(one_hot[None, :], obs.shape[0], axis=0)
        return np.concatenate([obs, one_hot], axis=-1)

class PerEpisodeRewardNormalizer(gym.Wrapper):
    def reset(self, **kwargs):
        self.episode_rewards = []
        return self.env.reset(**kwargs)

    def step(self, action):
        obs, reward, done, truncated, info = self.env.step(action)
        self.episode_rewards.append(reward)
        mean = np.mean(self.episode_rewards)
        std = np.std(self.episode_rewards) + 1e-8
        norm_reward = (reward - mean) / std
        return obs, norm_reward, done, truncated, info
# Training =============================================================
train_df = ohlcv_df[(ohlcv_df['date']>="2023-01-01") & (ohlcv_df['date']<"2023-07-01")]
test_df = ohlcv_df[(ohlcv_df['date']>="2023-07-01") & (ohlcv_df['date']<"2024-01-01")]
train_df = train_df[train_df['symbol'].isin(TOP2_STOCK_BY_SECTOR)]
test_df = test_df[test_df['symbol'].isin(TOP2_STOCK_BY_SECTOR)]

train_env =ENV_CLASS(train_df, episode_length=EPISODE_LENGTH, feature_cols=FEATURE_COLS)
test_env =ENV_CLASS(test_df, episode_length=EPISODE_LENGTH, feature_cols=FEATURE_COLS)
# Train on few episodes to prove a point only
train_seq = train_env.generate_episode_sequences(TOTAL_TIMESTEPS)
_test_seq = test_env.generate_episode_sequences(int(TOTAL_TIMESTEPS))
episodes = _test_seq
unique_episodes = {}
for ticker, start in episodes:
    if ticker not in unique_episodes:
        unique_episodes[ticker] = start
# Convert back to a list of tuples
test_seq = [(ticker, start) for ticker, start in unique_episodes.items()]

print(f"Training on {len(train_seq)} different episodes accross the top 2 stocks for each sector")
print(f"Testing on {len(test_seq)} different episodes accross the top 2 stocks for each sector")
def train_agent():
    
    
    
    train_env =ENV_CLASS(train_df, episode_length=EPISODE_LENGTH, feature_cols=FEATURE_COLS)
    eval_env =ENV_CLASS(test_df, episode_length=EPISODE_LENGTH, feature_cols=FEATURE_COLS)
    train_env.set_episode_sequence(train_seq)
    eval_env.set_episode_sequence(test_seq)
    
    train_env = PerEpisodeRewardNormalizer(RegimeAugmentingWrapper(train_env))
    eval_env = PerEpisodeRewardNormalizer(RegimeAugmentingWrapper(eval_env))
    checkpoint_callback = CheckpointCallback(
        save_freq=SAVE_FREQ, save_path=checkpoint_path, name_prefix=checkpoint_preffix
    )

    eval_callback = EvalCallback(
        eval_env, best_model_save_path=checkpoint_best_model,
        log_path=log_path, eval_freq=EVAL_FREQ, deterministic=True
    )

    model = RecurrentPPO(
        policy=TransformerPolicy,
        env=train_env,
        verbose=1,
        #tensorboard_log="./tensorboard_logs",
        n_steps=N_STEPS,
        batch_size=BATCH_SIZE,
        learning_rate=3e-4,
        gamma=0.99,
        gae_lambda=0.95,
        ent_coef=0.005,
        vf_coef=0.5,
        max_grad_norm=0.5,
        normalize_advantage=True,
        policy_kwargs=dict(share_features_extractor=True)
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[checkpoint_callback, eval_callback])
    model.save(save_path)

if __name__ == "__main__":
    train_agent()
# Out:
# Training on 1961 different episodes accross the top 2 stocks for each sector
# Testing on 22 different episodes accross the top 2 stocks for each sector
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 1.57     |
# | time/              |          |
# |    fps             | 135      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 800      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -1.87       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 2           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 1600        |
# | train/                  |             |
# |    approx_kl            | 0.009964771 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00215    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 8.9         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 0.475        |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 3            |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 0.0018414094 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00475     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 0.000691     |
# |    value_loss           | 6.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 4           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.011411612 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00273    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00929    |
# |    value_loss           | 8.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -1.21       |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 5           |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.014878971 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 4.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -0.691      |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 6           |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 4800        |
# | train/                  |             |
# |    approx_kl            | 0.007935429 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00104     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 5.02        |
# -----------------------------------------
# Eval num_timesteps=5000, episode_reward=-14.40 +/- 4.80
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | -14.4       |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.017902676 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.3         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 5.33        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -0.089   |
# | time/              |          |
# |    fps             | 23       |
# |    iterations      | 7        |
# |    time_elapsed    | 239      |
# |    total_timesteps | 5600     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 0.711        |
# | time/                   |              |
# |    fps                  | 23           |
# |    iterations           | 8            |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0103778485 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | -0.00942     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 3.48         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 9           |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.008609318 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | -0.0128     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 7.2         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 1.96         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 10           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0048785433 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | -0.0161      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 6.48         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 2.26        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 11          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 8800        |
# | train/                  |             |
# |    approx_kl            | 0.007842662 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000414    |
# |    value_loss           | 5.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 2.69        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 12          |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.009957589 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.0554      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00325     |
# |    value_loss           | 4.04        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=2.98 +/- 10.20
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | 2.98        |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010472106 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 5.1         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 2.9      |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 13       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 10400    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 3.62       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 14         |
# |    time_elapsed         | 517        |
# |    total_timesteps      | 11200      |
# | train/                  |            |
# |    approx_kl            | 0.00840297 |
# |    clip_fraction        | 0.0204     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.881     |
# |    explained_variance   | 0.184      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00336   |
# |    value_loss           | 5.01       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 3.99         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 15           |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0067560263 |
# |    clip_fraction        | 0.009        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.736        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -8.9e-05     |
# |    value_loss           | 2.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 4.54        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 16          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.015724786 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 4.37        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 102       |
# |    ep_rew_mean          | 5.42      |
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 17        |
# |    time_elapsed         | 644       |
# |    total_timesteps      | 13600     |
# | train/                  |           |
# |    approx_kl            | 0.0099179 |
# |    clip_fraction        | 0.064     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.889    |
# |    explained_variance   | 0.514     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.4       |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 0.00319   |
# |    value_loss           | 3.32      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 5.93        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 18          |
# |    time_elapsed         | 683         |
# |    total_timesteps      | 14400       |
# | train/                  |             |
# |    approx_kl            | 0.010501343 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00346     |
# |    value_loss           | 3.7         |
# -----------------------------------------
# Eval num_timesteps=15000, episode_reward=4.07 +/- 7.06
# Episode length: 102.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 102          |
# |    mean_reward          | 4.07         |
# | time/                   |              |
# |    total_timesteps      | 15000        |
# | train/                  |              |
# |    approx_kl            | 0.0063285287 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.00631      |
# |    value_loss           | 2.22         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 6.63     |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 19       |
# |    time_elapsed    | 722      |
# |    total_timesteps | 15200    |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 102       |
# |    ep_rew_mean          | 6.46      |
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 20        |
# |    time_elapsed         | 759       |
# |    total_timesteps      | 16000     |
# | train/                  |           |
# |    approx_kl            | 0.0373776 |
# |    clip_fraction        | 0.11      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.887    |
# |    explained_variance   | 0.56      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.909     |
# |    n_updates            | 190       |
# |    policy_gradient_loss | 0.00115   |
# |    value_loss           | 3.14      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 6.73         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 21           |
# |    time_elapsed         | 797          |
# |    total_timesteps      | 16800        |
# | train/                  |              |
# |    approx_kl            | 0.0058877417 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.666        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.0011       |
# |    value_loss           | 3.38         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.85        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 22          |
# |    time_elapsed         | 840         |
# |    total_timesteps      | 17600       |
# | train/                  |             |
# |    approx_kl            | 0.005846978 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 4.95        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 6.91         |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 23           |
# |    time_elapsed         | 883          |
# |    total_timesteps      | 18400        |
# | train/                  |              |
# |    approx_kl            | 0.0031003417 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.81         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.00268      |
# |    value_loss           | 4.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.84        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 24          |
# |    time_elapsed         | 923         |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.009656994 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.851       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00586     |
# |    value_loss           | 3.26        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=0.45 +/- 8.15
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | 0.445       |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.007003947 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 5.38        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 6.68     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 25       |
# |    time_elapsed    | 963      |
# |    total_timesteps | 20000    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.94        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 26          |
# |    time_elapsed         | 999         |
# |    total_timesteps      | 20800       |
# | train/                  |             |
# |    approx_kl            | 0.014550061 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.593       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000653   |
# |    value_loss           | 4.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.42        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 27          |
# |    time_elapsed         | 1036        |
# |    total_timesteps      | 21600       |
# | train/                  |             |
# |    approx_kl            | 0.020738028 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 3.98        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 7.49         |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 28           |
# |    time_elapsed         | 1077         |
# |    total_timesteps      | 22400        |
# | train/                  |              |
# |    approx_kl            | 0.0070338864 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.814       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.986        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000301    |
# |    value_loss           | 2.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.36        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 29          |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 23200       |
# | train/                  |             |
# |    approx_kl            | 0.011610093 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.36        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 30          |
# |    time_elapsed         | 1162        |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.013859275 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.843       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00658     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.3         |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 31          |
# |    time_elapsed         | 1200        |
# |    total_timesteps      | 24800       |
# | train/                  |             |
# |    approx_kl            | 0.021144062 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.765       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00679     |
# |    value_loss           | 2.29        |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=-6.23 +/- 9.41
# Episode length: 102.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 102        |
# |    mean_reward          | -6.23      |
# | time/                   |            |
# |    total_timesteps      | 25000      |
# | train/                  |            |
# |    approx_kl            | 0.04145962 |
# |    clip_fraction        | 0.0841     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.734     |
# |    explained_variance   | 0.73       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.906      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.00733    |
# |    value_loss           | 2.89       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 6.88     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 32       |
# |    time_elapsed    | 1239     |
# |    total_timesteps | 25600    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.13        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 33          |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 26400       |
# | train/                  |             |
# |    approx_kl            | 0.020999013 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.836       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0133      |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.93        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 34          |
# |    time_elapsed         | 1315        |
# |    total_timesteps      | 27200       |
# | train/                  |             |
# |    approx_kl            | 0.014986757 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.587       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00269     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.64        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 35          |
# |    time_elapsed         | 1359        |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.025117194 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00848     |
# |    value_loss           | 2.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.08        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 36          |
# |    time_elapsed         | 1401        |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.030300679 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.003       |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.65        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 37          |
# |    time_elapsed         | 1440        |
# |    total_timesteps      | 29600       |
# | train/                  |             |
# |    approx_kl            | 0.034409136 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.719       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00559     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=12.91 +/- 8.40
# Episode length: 102.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 102        |
# |    mean_reward          | 12.9       |
# | time/                   |            |
# |    total_timesteps      | 30000      |
# | train/                  |            |
# |    approx_kl            | 0.01776584 |
# |    clip_fraction        | 0.0771     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.668     |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.55       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.00566    |
# |    value_loss           | 2.24       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 7.22     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 38       |
# |    time_elapsed    | 1480     |
# |    total_timesteps | 30400    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 6.94        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 39          |
# |    time_elapsed         | 1517        |
# |    total_timesteps      | 31200       |
# | train/                  |             |
# |    approx_kl            | 0.026213843 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1           |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00551     |
# |    value_loss           | 1.48        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 6.67       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 40         |
# |    time_elapsed         | 1555       |
# |    total_timesteps      | 32000      |
# | train/                  |            |
# |    approx_kl            | 0.02992807 |
# |    clip_fraction        | 0.0714     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.408      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00825    |
# |    value_loss           | 2.56       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 7.18       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 41         |
# |    time_elapsed         | 1602       |
# |    total_timesteps      | 32800      |
# | train/                  |            |
# |    approx_kl            | 0.05915028 |
# |    clip_fraction        | 0.0735     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.649     |
# |    explained_variance   | 0.784      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.987      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0107     |
# |    value_loss           | 2.37       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.31        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 42          |
# |    time_elapsed         | 1648        |
# |    total_timesteps      | 33600       |
# | train/                  |             |
# |    approx_kl            | 0.056160696 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.577       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0179      |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 7.8         |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 43          |
# |    time_elapsed         | 1689        |
# |    total_timesteps      | 34400       |
# | train/                  |             |
# |    approx_kl            | 0.025995357 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.944       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00822     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# Eval num_timesteps=35000, episode_reward=1.99 +/- 6.53
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | 1.99        |
# | time/                   |             |
# |    total_timesteps      | 35000       |
# | train/                  |             |
# |    approx_kl            | 0.049498804 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.847       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00202     |
# |    value_loss           | 2.25        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 7.81     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 44       |
# |    time_elapsed    | 1729     |
# |    total_timesteps | 35200    |
# ---------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 102      |
# |    ep_rew_mean          | 8.15     |
# | time/                   |          |
# |    fps                  | 20       |
# |    iterations           | 45       |
# |    time_elapsed         | 1765     |
# |    total_timesteps      | 36000    |
# | train/                  |          |
# |    approx_kl            | 0.007849 |
# |    clip_fraction        | 0.0779   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.637   |
# |    explained_variance   | 0.672    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.548    |
# |    n_updates            | 440      |
# |    policy_gradient_loss | 0.00257  |
# |    value_loss           | 1.62     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 8.18        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 46          |
# |    time_elapsed         | 1801        |
# |    total_timesteps      | 36800       |
# | train/                  |             |
# |    approx_kl            | 0.015826792 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.327       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0052      |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 8.95        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 47          |
# |    time_elapsed         | 1843        |
# |    total_timesteps      | 37600       |
# | train/                  |             |
# |    approx_kl            | 0.023854688 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.858       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 9.27        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 48          |
# |    time_elapsed         | 1889        |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.020817285 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.54        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 9.15        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 49          |
# |    time_elapsed         | 1930        |
# |    total_timesteps      | 39200       |
# | train/                  |             |
# |    approx_kl            | 0.008190799 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.391       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00545     |
# |    value_loss           | 2.54        |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=3.99 +/- 5.45
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | 3.99        |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.044217154 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00276     |
# |    value_loss           | 2.07        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 9.67     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 50       |
# |    time_elapsed    | 1972     |
# |    total_timesteps | 40000    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 9.52        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 51          |
# |    time_elapsed         | 2007        |
# |    total_timesteps      | 40800       |
# | train/                  |             |
# |    approx_kl            | 0.020734824 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.000352    |
# |    value_loss           | 3.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 9.85        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 52          |
# |    time_elapsed         | 2046        |
# |    total_timesteps      | 41600       |
# | train/                  |             |
# |    approx_kl            | 0.017089942 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.586       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 1.15        |
# -----------------------------------------
# ...
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.000626    |
# |    value_loss           | 0.762       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 19.4       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 234        |
# |    time_elapsed         | 9227       |
# |    total_timesteps      | 187200     |
# | train/                  |            |
# |    approx_kl            | 0.01997266 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.504     |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.135      |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | -0.00409   |
# |    value_loss           | 0.606      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 102       |
# |    ep_rew_mean          | 19.9      |
# | time/                   |           |
# |    fps                  | 20        |
# |    iterations           | 235       |
# |    time_elapsed         | 9264      |
# |    total_timesteps      | 188000    |
# | train/                  |           |
# |    approx_kl            | 0.0379064 |
# |    clip_fraction        | 0.134     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.52     |
# |    explained_variance   | 0.99      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.113     |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | -0.00216  |
# |    value_loss           | 0.346     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 236         |
# |    time_elapsed         | 9300        |
# |    total_timesteps      | 188800      |
# | train/                  |             |
# |    approx_kl            | 0.034662798 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.288       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 0.297       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 102       |
# |    ep_rew_mean          | 20.6      |
# | time/                   |           |
# |    fps                  | 20        |
# |    iterations           | 237       |
# |    time_elapsed         | 9335      |
# |    total_timesteps      | 189600    |
# | train/                  |           |
# |    approx_kl            | 0.0549301 |
# |    clip_fraction        | 0.185     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.499    |
# |    explained_variance   | 0.987     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.092     |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | 0.00169   |
# |    value_loss           | 0.419     |
# ---------------------------------------
# Eval num_timesteps=190000, episode_reward=-5.77 +/- 8.12
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | -5.77       |
# | time/                   |             |
# |    total_timesteps      | 190000      |
# | train/                  |             |
# |    approx_kl            | 0.061972167 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0685      |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.273       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 238      |
# |    time_elapsed    | 9380     |
# |    total_timesteps | 190400   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 21.3        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 239         |
# |    time_elapsed         | 9423        |
# |    total_timesteps      | 191200      |
# | train/                  |             |
# |    approx_kl            | 0.043054983 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.244       |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00645     |
# |    value_loss           | 0.637       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 21.6        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 240         |
# |    time_elapsed         | 9464        |
# |    total_timesteps      | 192000      |
# | train/                  |             |
# |    approx_kl            | 0.048040703 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.28        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.00425     |
# |    value_loss           | 0.538       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 241         |
# |    time_elapsed         | 9502        |
# |    total_timesteps      | 192800      |
# | train/                  |             |
# |    approx_kl            | 0.040764347 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.546       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 21.9       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 242        |
# |    time_elapsed         | 9538       |
# |    total_timesteps      | 193600     |
# | train/                  |            |
# |    approx_kl            | 0.08508023 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.412     |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00512    |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00699   |
# |    value_loss           | 0.715      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 22.6       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 243        |
# |    time_elapsed         | 9573       |
# |    total_timesteps      | 194400     |
# | train/                  |            |
# |    approx_kl            | 0.11729203 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.36      |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0601     |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.00834   |
# |    value_loss           | 0.464      |
# ----------------------------------------
# Eval num_timesteps=195000, episode_reward=-2.51 +/- 3.01
# Episode length: 102.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 102         |
# |    mean_reward          | -2.51       |
# | time/                   |             |
# |    total_timesteps      | 195000      |
# | train/                  |             |
# |    approx_kl            | 0.037418045 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.423      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.614       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 0.975       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 22.8     |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 244      |
# |    time_elapsed    | 9614     |
# |    total_timesteps | 195200   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 22.6       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 245        |
# |    time_elapsed         | 9655       |
# |    total_timesteps      | 196000     |
# | train/                  |            |
# |    approx_kl            | 0.13539763 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.379     |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.398      |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | 0.00819    |
# |    value_loss           | 0.916      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 23          |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 246         |
# |    time_elapsed         | 9698        |
# |    total_timesteps      | 196800      |
# | train/                  |             |
# |    approx_kl            | 0.052174922 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.274       |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | 0.00414     |
# |    value_loss           | 0.716       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 23.5       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 247        |
# |    time_elapsed         | 9738       |
# |    total_timesteps      | 197600     |
# | train/                  |            |
# |    approx_kl            | 0.07404409 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.349     |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.132      |
# |    n_updates            | 2460       |
# |    policy_gradient_loss | -0.0081    |
# |    value_loss           | 0.41       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 23.7        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 248         |
# |    time_elapsed         | 9774        |
# |    total_timesteps      | 198400      |
# | train/                  |             |
# |    approx_kl            | 0.044042654 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0383      |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | 0.00248     |
# |    value_loss           | 0.306       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | 23.7       |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 249        |
# |    time_elapsed         | 9809       |
# |    total_timesteps      | 199200     |
# | train/                  |            |
# |    approx_kl            | 0.08533076 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.363     |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0134    |
# |    n_updates            | 2480       |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.504      |
# ----------------------------------------
# Eval num_timesteps=200000, episode_reward=4.38 +/- 8.16
# Episode length: 102.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 102        |
# |    mean_reward          | 4.38       |
# | time/                   |            |
# |    total_timesteps      | 200000     |
# | train/                  |            |
# |    approx_kl            | 0.06102253 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.378     |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.048      |
# |    n_updates            | 2490       |
# |    policy_gradient_loss | -0.00099   |
# |    value_loss           | 0.634      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 24       |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 250      |
# |    time_elapsed    | 9847     |
# |    total_timesteps | 200000   |
# ---------------------------------

# %%
n = Notify(experiment_tracker.project)
n.info('DONE')

# %%
# === Imports ===
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import ttest_ind, mannwhitneyu

from sb3_contrib import RecurrentPPO
#from src.env.base_timeseries_trading_env import SequenceAwareCumulativeTradingEnv
from src.defaults import TOP2_STOCK_BY_SECTOR, EPISODE_LENGTH
from src.data.feature_pipeline import load_base_dataframe
#from src.env.base_timeseries_trading_env import RegimeAugmentingWrapper


# === Config ===
N_EVAL_EPISODES = 5
MODEL_PATH = save_path

# === Load Data ===
ohlcv_df = load_base_dataframe()
test_df = ohlcv_df[(ohlcv_df['date'] >= "2023-07-01") & (ohlcv_df['date'] < "2024-01-01")]
test_df = test_df[test_df['symbol'].isin(TOP2_STOCK_BY_SECTOR)]


# === Evaluation Logic ===
def evaluate_agent(agent, env, n_episodes=22):
    episode_metrics = []
    action_counts = []


    for _ in tqdm(range(n_episodes), desc="Evaluating Agent"):
        obs, _ = env.reset()
        #print(">>> [Eval] Obs shape:", obs.shape)  # Check input dimensions

        done = False
        state = None
        rewards = []
        infos = []

        while not done:
            action, state = agent.predict(obs, state=state, deterministic=True)
            #print(action)
            #print(env.action_counts)
            obs, reward, done, _, info = env.step(action)
            rewards.append(reward)
            infos.append(info)

        _env = env.env.env
        
        agent_wealth = infos[-1].get("final_wealth", np.nan)         # Your agent
        market_wealth = np.prod(1 + _env.episode_df['market_return_1d'].values)       # Market index
        alpha = agent_wealth - market_wealth              # Skill
        metrics = {
            "total_reward": np.sum(rewards),
            "final_wealth": infos[-1].get("final_wealth", np.nan),
            "market_wealth": market_wealth,
            "calmar": infos[-1].get("calmar", np.nan),
            "sharpe": infos[-1].get("episode_sharpe", np.nan),
            "sortino": infos[-1].get("episode_sortino", np.nan),
            "alpha":alpha,
            "episode_id": env.env.env.episode_counter,
            "regime": infos[-1].get("regime",np.nan)
        }


        episode_metrics.append(metrics)
    
    print(">>> [Eval] Action counts:", pd.Series(action_counts).value_counts())
    return pd.DataFrame(episode_metrics)


def evaluate_random_agent(env, n_episodes=22):
    episode_metrics = []

    for i in tqdm(range(n_episodes), desc="Evaluating Random Agent"):
        obs, _ = env.reset()
        done = False
        rewards = []
        infos = []

        while not done:
            action = env.action_space.sample()
            obs, reward, done, _, info = env.step(action)
            rewards.append(reward)
            infos.append(info)

        _env = env.env.env
        
        agent_wealth = infos[-1].get("final_wealth", np.nan)         # Your agent
        market_wealth = np.prod(1 + _env.episode_df['market_return_1d'].values)       # Market index
        alpha = agent_wealth - market_wealth              # Skill
        metrics = {
            "total_reward": np.sum(rewards),
            "final_wealth": infos[-1].get("final_wealth", np.nan),
            "market_wealth": market_wealth,
            "calmar": infos[-1].get("calmar", np.nan),
            "sharpe": infos[-1].get("episode_sharpe", np.nan),
            "sortino": infos[-1].get("episode_sortino", np.nan),
            "alpha":alpha,
            "episode_id": env.env.env.episode_counter,
            "regime": infos[-1].get("regime",np.nan)
        }
        episode_metrics.append(metrics)

    return pd.DataFrame(episode_metrics)


# === Run Evaluation ===

model = RecurrentPPO.load(MODEL_PATH)

def make_test_env():
    eval_env =ENV_CLASS(test_df, episode_length=EPISODE_LENGTH, feature_cols=FEATURE_COLS)
    eval_env.set_episode_sequence(test_seq)
    return PerEpisodeRewardNormalizer(RegimeAugmentingWrapper(eval_env)) #RegimeAugmentingWrapper(ENV_CLASS(test_df, episode_length=EPISODE_LENGTH,feature_cols=FEATURE_COLS))

random_agent_df = evaluate_random_agent(make_test_env(), n_episodes=N_EVAL_EPISODES)
ppo_agent_df = evaluate_agent(model, make_test_env(), n_episodes=N_EVAL_EPISODES)


ppo_agent_df["agent"] = "recurrent_ppo"
random_agent_df["agent"] = "random"
results_df = pd.concat([ppo_agent_df, random_agent_df])


# === Plotting ===
melted = results_df.melt(id_vars="agent", var_name="metric", value_name="value")
plt.figure(figsize=(16, 10))
sns.boxplot(data=melted, x="metric", y="value", hue="agent")
plt.title("Agent Performance Comparison (Random vs Recurrent PPO)")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()


# === Statistical Tests ===
comparison_results = []

for metric in ppo_agent_df.columns[:-1]:  # exclude 'agent'
    a = ppo_agent_df[metric].dropna()
    b = random_agent_df[metric].dropna()

    # Skip if either is empty
    if len(a) == 0 or len(b) == 0:
        print(f"Skipping metric {metric}: empty values")
        continue

    t_stat, p_val_t = ttest_ind(a, b)
    u_stat, p_val_u = mannwhitneyu(a, b, alternative='two-sided')
    comparison_results.append({
        "metric": metric,
        "t-test p-value": p_val_t,
        "mann-whitney p-value": p_val_u
    })

comparison_df = pd.DataFrame(comparison_results)
comparison_df
# Out:
# >>> [Eval] Obs shape: (10, 28)
# >>> [Eval] Obs shape: (10, 28)
# >>> [Eval] Obs shape: (10, 28)
# >>> [Eval] Obs shape: (10, 28)
# >>> [Eval] Obs shape: (10, 28)
# >>> [Eval] Action counts: Series([], Name: count, dtype: int64)
#          metric  t-test p-value  mann-whitney p-value
# 0  total_reward        0.329916              0.309524
# 1  final_wealth        0.000012              0.007937
# 2        calmar        0.000323              0.007937
# 3        sharpe        0.269913              0.420635
# 4       sortino        0.159818              0.150794

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=ppo_agent_df, x='market_wealth', y='alpha', hue='regime', alpha=0.2)
# Out:
# <Axes: xlabel='agent', ylabel='final_wealth'>

# %%
sns.scatterplot(data=ppo_agent_df, x='market_wealth', y='alpha', hue='agent')
plt.axhline(0, linestyle='--', color='red', label='Alpha = 0')
plt.legend()
plt.show()
# Out:
# <Axes: xlabel='total_reward', ylabel='final_wealth'>

# %%
ppo_agent_df['alpha_ratio'] = ppo_agent_df['alpha'] / np.abs(ppo_agent_df['market_wealth'] + 1e-8)
sns.boxplot(data=ppo_agent_df, x='agent', y='alpha_ratio')

# %%
for f in FEATURE_COLS:
    print(f"{f}: {train_env.episode_df[f].corr(train_env.episode_df['return_1d'].shift(-1)):.4f}")
# Out:
# candle_body: 0.0393
# candle_change: 0.1278
# day_of_month: 0.0892
# day_of_week: 0.1376
# lower_shadow: 0.1453
# market_return_1d: 0.0293
# order_flow: -0.0755
# order_flow_change: 0.0458
# overnight_price_change: -0.1429
# price_change: -0.1481
# return_1d: -0.1481
# trade_count_change: 0.1501
# upper_shadow: -0.2076
# vix_norm: 0.0561
# volume_change: 0.2046
# vwap_change: -0.1310

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
df = train_env.episode_df.dropna()
X = df[FEATURE_COLS]
y = df['return_1d'].shift(-1).fillna(0)
model.fit(X, y)
importances = model.feature_importances_

# %%
importances
# Out:
# array([0.0341971 , 0.08832226, 0.01672027, 0.0458513 , 0.07812732,
#        0.03731287, 0.02379431, 0.02857699, 0.02942792, 0.16061361,
#        0.        , 0.04409018, 0.13293046, 0.07080062, 0.07806453,
#        0.13117015], dtype=float32)

# %%
FEATURE_COLS
# Out:
# ['candle_body',
#  'candle_change',
#  'day_of_month',
#  'day_of_week',
#  'lower_shadow',
#  'market_return_1d',
#  'order_flow',
#  'order_flow_change',
#  'overnight_price_change',
#  'price_change',
#  'return_1d',
#  'trade_count_change',
#  'upper_shadow',
#  'vix_norm',
#  'volume_change',
#  'vwap_change']

# %%
import matplotlib.pyplot as plt
feat_importance_df = pd.DataFrame({
    "feature": FEATURE_COLS,
    "importance": importances
}).sort_values(by="importance", ascending=False)

print(feat_importance_df)
plt.figure(figsize=(10, 6))
plt.barh(feat_importance_df['feature'], feat_importance_df['importance'])
plt.title("XGBoost Feature Importances for Next-Day Return")
plt.gca().invert_yaxis()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#                    feature  importance
# 9             price_change    0.160614
# 12            upper_shadow    0.132930
# 15             vwap_change    0.131170
# 1            candle_change    0.088322
# 4             lower_shadow    0.078127
# 14           volume_change    0.078065
# 13                vix_norm    0.070801
# 3              day_of_week    0.045851
# 11      trade_count_change    0.044090
# 5         market_return_1d    0.037313
# 0              candle_body    0.034197
# 8   overnight_price_change    0.029428
# 7        order_flow_change    0.028577
# 6               order_flow    0.023794
# 2             day_of_month    0.016720
# 10               return_1d    0.000000
