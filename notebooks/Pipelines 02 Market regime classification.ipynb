# %% [markdown]
# # 03 - Predictability & Universe Filtering
#
# 1. Compute rolling predictability metrics for each ticker
# 2. Visualize and compare scores across universe and time
# 3. Select top-N most “learnable” tickers for RL agent
# 4. Document all decisions, assumptions, and open questions

# %%
# SETUP: Imports & Paths ===========================
import jupyter
from src.utils.system import boot
import os
import pandas as pd

boot()
from tqdm import tqdm
from src.data.feature_pipeline import basic_chart_features,load_base_dataframe
from src.predictability.easiness import rolling_sharpe, rolling_r2, rolling_info_ratio, rolling_autocorr
from src.predictability.pipeline import generate_universe_easiness_report
from IPython import display
import warnings
import numpy.linalg as la

# Suppress HMM warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Francisco Sá\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# LOAD OHLCV ==========================================
ohlcv = load_base_dataframe()
ohlcv.tail()
ohlcv.drop(columns=['sector_id','industry_id'],inplace=True)

# %%
# CROP THE SAMPLE =======================================
tickers = ohlcv['symbol'].unique()

# %%
# Adaptive Market Regime Classification Pipeline (Per Stock + Timeframe)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from hmmlearn.hmm import GaussianHMM
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import RobustScaler
from collections import defaultdict
import warnings
import numpy.linalg as la

# Suppress HMM warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# Utility function to check positive-definiteness
def is_positive_definite(matrix):
    try:
        la.cholesky(matrix)
        return True
    except la.LinAlgError:
        return False

# 1. Feature Engineering
def compute_regime_features(df):
    df['return'] = df['close'].pct_change()
    df['volatility'] = df['return'].rolling(21).std()
    df['momentum'] = df['close'] / df['close'].shift(21) - 1
    df['drawdown'] = (df['close'] / df['close'].cummax()) - 1
    df['rolling_corr'] = df['return'].rolling(21).corr(df['return'].shift(1))
    return df.dropna()

# 2. Try Different Regime Models
def try_regime_models(X):
    models = {
        "kmeans": KMeans(n_clusters=3, random_state=0),
        "gmm": GaussianMixture(n_components=3, covariance_type='full', random_state=0),
        "hmm": GaussianHMM(n_components=3, covariance_type='diag', n_iter=200, tol=1e-3)
    }

    results = {}
    for name, model in models.items():
        try:
            if name == "hmm":
                model.fit(X)
                if not all(is_positive_definite(np.diag(cov) if cov.ndim == 1 else cov) for cov in model.covars_):
                    raise ValueError("HMM covariance not positive-definite.")
                labels = model.predict(X)
            else:
                labels = model.fit_predict(X)
            score = silhouette_score(X, labels)
            results[name] = {'model': model, 'labels': labels, 'score': score}
        except Exception as e:
            print(f"{name} failed: {e}")
    return results

# Standardize features using robust scaling
def standardize_features(X):
    return pd.DataFrame(RobustScaler().fit_transform(X), columns=X.columns, index=X.index)

# 3. Walk-Forward Adaptive Optimization by Stock-Timeframe
def walk_forward_regime_search_grouped(df, group_col='symbol', window_size=252, step=21):
    all_results = defaultdict(list)

    for group, df_group in tqdm(df.groupby(group_col)):
        df_group = compute_regime_features(df_group)
        for start in range(0, len(df_group) - window_size, step):
            X = df_group.iloc[start:start+window_size][['return', 'volatility', 'momentum', 'drawdown', 'rolling_corr']]
            X = standardize_features(X)
            models = try_regime_models(X)
            for name, result in models.items():
                all_results[(group, name)].append({
                    'score': result['score'],
                    'labels': result['labels'],
                    'start': start,
                    'end': start+window_size
                })
    return all_results

# 4. Summarize Results Per Group
def summarize_results(results):
    summary = []
    for key, res_list in results.items():
        group, name = key
        scores = [r['score'] for r in res_list]
        summary.append({
            'group': group,
            'model': name,
            'avg_score': np.median(scores),
            'std_score': np.std(scores),
            'num_windows': len(scores)
        })
    return pd.DataFrame(summary).sort_values(['group', 'avg_score'], ascending=[True, False])

# 5. Plotting Function
def plot_regimes(df, labels, title="Regime Assignment"):
    df = df.copy()
    df['regime'] = labels
    df['close'].plot(figsize=(15, 4), title=title, color='black', alpha=0.3)
    for regime in sorted(df['regime'].unique()):
        df[df['regime'] == regime]['close'].plot(label=f'Regime {regime}', alpha=0.7)
    plt.legend()
    plt.show()

# 6. Final Report Generator (Markdown)
def generate_report(summary_df):
    report_lines = [
        "# 📈 Adaptive Market Regime Classification Report\n",
        "\n",
        "## Model Performance by Stock\n",
        summary_df.to_markdown(index=False),
        "\n",
        "---\n",
        "## Interpretation\n",
        "- Higher silhouette score → better cluster separation.\n",
        "- Monitor which model works best for each stock over time.\n",
        "- Combine regime classification with strategy backtests.\n"
    ]
    with open("regime_classification_report.md", "w") as f:
        f.write("\n".join(report_lines))
    print("Report saved as 'regime_classification_report.md'")

# Example Usage:
# df = pd.read_csv("your_data.csv")
df = ohlcv.copy()
results = walk_forward_regime_search_grouped(df)
summary = summarize_results(results)
generate_report(summary)
for (symbol, model) in results:
    last = results[(symbol, model)][-1]
    df_group = compute_regime_features(df[df['symbol'] == symbol])
    plot_regimes(df_group.iloc[last['start']:last['end']], last['labels'], title=f"{symbol} - {model} Regimes")
# Out:
#   0%|          | 1/504 [00:02<22:45,  2.71s/it]Model is not converging.  Current: -899.819393217708 is not greater than -899.8192312808463. Delta is -0.00016193686167298438
# Model is not converging.  Current: -863.6075602575104 is not greater than -863.6075576550219. Delta is -2.602488507363887e-06
# Model is not converging.  Current: -783.7624015615747 is not greater than -783.7612282906892. Delta is -0.0011732708854879093
#   0%|          | 2/504 [00:05<21:06,  2.52s/it]Model is not converging.  Current: -980.9831885888506 is not greater than -980.9819133784779. Delta is -0.0012752103726825226
# Model is not converging.  Current: -1236.049309401171 is not greater than -1236.0475552929342. Delta is -0.0017541082368097705
#   1%|          | 3/504 [00:06<18:19,  2.19s/it]Model is not converging.  Current: -886.1019695099558 is not greater than -886.1018834336473. Delta is -8.60763084347127e-05
# Model is not converging.  Current: -978.8077781441153 is not greater than -978.807728237265. Delta is -4.9906850335901254e-05
#   1%|          | 5/504 [00:11<18:11,  2.19s/it]Model is not converging.  Current: -1056.746599166482 is not greater than -1056.7465064084995. Delta is -9.275798242924793e-05
#   1%|          | 6/504 [00:14<19:54,  2.40s/it]Model is not converging.  Current: -1017.1900568659879 is not greater than -1017.1900072059035. Delta is -4.966008441442682e-05
#   2%|▏         | 9/504 [00:20<19:12,  2.33s/it]Model is not converging.  Current: -1007.2369172596377 is not greater than -1007.2367405189939. Delta is -0.0001767406438375474
#   2%|▏         | 12/504 [00:27<18:23,  2.24s/it]Model is not converging.  Current: -1214.4098286761412 is not greater than -1214.4097993976698. Delta is -2.9278471401994466e-05
# Model is not converging.  Current: -1103.1925233401062 is not greater than -1103.1911551229255. Delta is -0.001368217180697684
#  11%|█         | 55/504 [02:03<15:35,  2.08s/it]Model is not converging.  Current: -1080.3363386636568 is not greater than -1080.3363033158803. Delta is -3.534777647473675e-05
#  11%|█         | 56/504 [02:06<16:48,  2.25s/it]Model is not converging.  Current: -1037.7714093355125 is not greater than -1037.7713902913404. Delta is -1.904417217701848e-05
# Model is not converging.  Current: -893.6159377699214 is not greater than -893.6159253504117. Delta is -1.2419509744177049e-05
#  11%|█▏        | 57/504 [02:08<16:46,  2.25s/it]Model is not converging.  Current: -989.3263540806912 is not greater than -989.3253986174807. Delta is -0.0009554632105164274
# Model is not converging.  Current: -967.1618929312039 is not greater than -967.1618182716129. Delta is -7.465959095043218e-05
#  12%|█▏        | 60/504 [02:14<14:52,  2.01s/it]Model is not converging.  Current: -952.0714856225435 is not greater than -952.0713179909776. Delta is -0.00016763156588694983
#  12%|█▏        | 61/504 [02:16<14:27,  1.96s/it]Model is not converging.  Current: -1134.4272354175644 is not greater than -1134.426958479521. Delta is -0.00027693804327100224
#  12%|█▎        | 63/504 [02:20<15:46,  2.15s/it]Model is not converging.  Current: -904.4823715001245 is not greater than -904.4823656798394. Delta is -5.8202850823363406e-06
#  13%|█▎        | 65/504 [02:25<16:18,  2.23s/it]Model is not converging.  Current: -1052.9446118710152 is not greater than -1052.9445958608633. Delta is -1.6010151966838748e-05
#  13%|█▎        | 68/504 [02:31<14:59,  2.06s/it]Model is not converging.  Current: -994.5873031401969 is not greater than -994.5872854203589. Delta is -1.771983806975186e-05
#  15%|█▍        | 74/504 [02:45<15:27,  2.16s/it]Model is not converging.  Current: -1064.9572049271128 is not greater than -1064.956823391058. Delta is -0.0003815360548742319
#  15%|█▌        | 77/504 [02:52<15:46,  2.22s/it]Model is not converging.  Current: -1022.1227149244046 is not greater than -1022.1227048734249. Delta is -1.005097965389723e-05
#  16%|█▌        | 79/504 [02:58<18:17,  2.58s/it]Model is not converging.  Current: -842.8237142884241 is not greater than -842.8232944690646. Delta is -0.00041981935942203563
#  16%|█▋        | 82/504 [03:04<16:00,  2.28s/it]Model is not converging.  Current: -854.1808214497347 is not greater than -854.1808174927601. Delta is -3.956974637731037e-06
# Model is not converging.  Current: -1108.0990761765715 is not greater than -1108.0990747164622. Delta is -1.4601093880628468e-06
#  16%|█▋        | 83/504 [03:06<15:25,  2.20s/it]Model is not converging.  Current: -966.9910222212519 is not greater than -966.9909214171353. Delta is -0.00010080411664148414
#  17%|█▋        | 84/504 [03:08<15:54,  2.27s/it]Model is not converging.  Current: -903.200645936634 is not greater than -903.2005851052246. Delta is -6.0831409427919425e-05
# Model is not converging.  Current: -1041.6729674265875 is not greater than -1041.6653920274266. Delta is -0.007575399160941743
#  17%|█▋        | 85/504 [03:11<16:33,  2.37s/it]Model is not converging.  Current: -920.8533703815071 is not greater than -920.8531374172077. Delta is -0.0002329642994709502
#  55%|█████▍    | 275/504 [12:01<09:51,  2.58s/it]Model is not converging.  Current: -1206.7388594570857 is not greater than -1206.7378018474892. Delta is -0.001057609596500697
#  55%|█████▍    | 276/504 [12:04<10:20,  2.72s/it]Model is not converging.  Current: -959.7858982753066 is not greater than -959.7858982553034. Delta is -2.000319909711834e-08
#  55%|█████▍    | 277/504 [12:06<09:52,  2.61s/it]Model is not converging.  Current: -799.3483489462405 is not greater than -799.3479515598063. Delta is -0.00039738643420150765
#  55%|█████▌    | 278/504 [12:08<09:43,  2.58s/it]Model is not converging.  Current: -956.5235759753613 is not greater than -956.5234488247694. Delta is -0.00012715059187939914
# Model is not converging.  Current: -1102.0171532414215 is not greater than -1102.0170997305243. Delta is -5.351089725991187e-05
#  55%|█████▌    | 279/504 [12:11<10:09,  2.71s/it]Model is not converging.  Current: -1139.8987237624833 is not greater than -1139.8987234321678. Delta is -3.3031551538442727e-07
#  56%|█████▌    | 280/504 [12:15<10:34,  2.83s/it]Model is not converging.  Current: -1039.352018196752 is not greater than -1039.3518423948397. Delta is -0.0001758019122917176
# Model is not converging.  Current: -1123.396804930608 is not greater than -1123.3946556830233. Delta is -0.0021492475846116577
#  56%|█████▌    | 283/504 [12:22<09:37,  2.61s/it]Model is not converging.  Current: -986.9269635559472 is not greater than -986.8400226956834. Delta is -0.08694086026378045
# Model is not converging.  Current: -979.6284192855969 is not greater than -979.627930132306. Delta is -0.0004891532909141461
# Model is not converging.  Current: -1047.799663070425 is not greater than -1047.7979931487516. Delta is -0.00166992167328317
#  56%|█████▋    | 284/504 [12:25<09:34,  2.61s/it]Model is not converging.  Current: -912.5144753006483 is not greater than -912.5130349984782. Delta is -0.001440302170067298
# Model is not converging.  Current: -704.1716054201879 is not greater than -704.1712642025626. Delta is -0.00034121762530503474
# Model is not converging.  Current: -737.6555568902415 is not greater than -737.6553220457995. Delta is -0.00023484444204768806
#  57%|█████▋    | 287/504 [12:35<11:28,  3.17s/it]Model is not converging.  Current: -864.4519674932345 is not greater than -864.4519552701079. Delta is -1.2223126645949378e-05
#  57%|█████▋    | 288/504 [12:37<10:51,  3.02s/it]Model is not converging.  Current: -845.1745582553037 is not greater than -845.1745100204738. Delta is -4.823482993288053e-05
#  58%|█████▊    | 292/504 [12:51<11:11,  3.17s/it]Model is not converging.  Current: -1186.6887484076722 is not greater than -1186.688726277864. Delta is -2.2129808257886907e-05
#  58%|█████▊    | 293/504 [12:53<10:00,  2.84s/it]Model is not converging.  Current: -891.002818765153 is not greater than -891.0001091107181. Delta is -0.002709654434966069
#  58%|█████▊    | 294/504 [12:55<09:35,  2.74s/it]Model is not converging.  Current: -907.7131951906892 is not greater than -907.7130906895108. Delta is -0.00010450117849813978
#  60%|█████▉    | 300/504 [13:13<09:08,  2.69s/it]Model is not converging.  Current: -939.9756656032642 is not greater than -939.9752930434415. Delta is -0.00037255982272199617
#  80%|████████  | 405/504 [18:49<04:38,  2.81s/it]Model is not converging.  Current: -1047.8039755860766 is not greater than -1047.8027330361201. Delta is -0.0012425499564869824
#  81%|████████  | 409/504 [19:00<04:12,  2.65s/it]Model is not converging.  Current: -1013.0587634219748 is not greater than -1013.058612105349. Delta is -0.00015131662587464234
#  81%|████████▏ | 410/504 [19:03<04:01,  2.57s/it]Model is not converging.  Current: -949.9746935665175 is not greater than -949.9716007131855. Delta is -0.0030928533320775387
#  82%|████████▏ | 413/504 [19:11<04:17,  2.83s/it]Model is not converging.  Current: -964.2150123642896 is not greater than -964.214947129871. Delta is -6.523441857098078e-05
#  83%|████████▎ | 419/504 [19:24<03:17,  2.32s/it]Model is not converging.  Current: -895.7481821526433 is not greater than -895.7481360521084. Delta is -4.6100534859760955e-05
#  83%|████████▎ | 420/504 [19:27<03:39,  2.61s/it]Model is not converging.  Current: -986.6965504787619 is not greater than -986.6964565980547. Delta is -9.388070714066998e-05
#  84%|████████▍ | 424/504 [19:37<03:15,  2.45s/it]Model is not converging.  Current: -755.2647327634072 is not greater than -755.2647326639321. Delta is -9.947507351171225e-08
# Model is not converging.  Current: -933.0691220374849 is not greater than -933.0691037816035. Delta is -1.825588140036416e-05
#  85%|████████▌ | 429/504 [19:51<03:15,  2.60s/it]Model is not converging.  Current: -1245.8123915462254 is not greater than -1245.8105071759974. Delta is -0.0018843702280264552
# Model is not converging.  Current: -1081.520595007849 is not greater than -1081.5205896511616. Delta is -5.356687324820086e-06
#  86%|████████▌ | 431/504 [19:56<03:19,  2.73s/it]Model is not converging.  Current: -878.7615457170658 is not greater than -878.761535206468. Delta is -1.0510597803659039e-05
#  86%|████████▌ | 434/504 [20:04<03:01,  2.59s/it]Model is not converging.  Current: -1253.6008045765977 is not greater than -1253.6002162726388. Delta is -0.0005883039589207328
#  87%|████████▋ | 436/504 [20:09<02:41,  2.38s/it]Model is not converging.  Current: -926.6542198110805 is not greater than -926.6542174748569. Delta is -2.3362235879176296e-06
#  87%|████████▋ | 438/504 [20:15<03:02,  2.77s/it]Model is not converging.  Current: -1130.3383862307062 is not greater than -1130.3383787841126. Delta is -7.446593599524931e-06
#  87%|████████▋ | 439/504 [20:18<02:58,  2.75s/it]Model is not converging.  Current: -1056.0771880251673 is not greater than -1056.0771811765255. Delta is -6.8486417603708105e-06
#  87%|████████▋ | 440/504 [20:20<02:48,  2.63s/it]Model is not converging.  Current: -1181.5460450973953 is not greater than -1181.5458764175992. Delta is -0.00016867979616108641
#  88%|████████▊ | 441/504 [20:22<02:37,  2.49s/it]Model is not converging.  Current: -1167.2928227455402 is not greater than -1167.292788329346. Delta is -3.441619423938391e-05
#  88%|████████▊ | 442/504 [20:25<02:34,  2.49s/it]Model is not converging.  Current: -956.3316100775003 is not greater than -956.3315989491774. Delta is -1.1128322853437567e-05
# Model is not converging.  Current: -951.2716085546339 is not greater than -951.2715918585218. Delta is -1.6696112083991466e-05
#  88%|████████▊ | 443/504 [20:27<02:34,  2.54s/it]Model is not converging.  Current: -1377.3213879009688 is not greater than -1377.3213822078196. Delta is -5.693149205399095e-06
#  88%|████████▊ | 446/504 [20:36<02:38,  2.73s/it]Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# hmm failed: transmat_ rows must sum to 1 (got row sums of [1. 1. 0.])
#  89%|████████▉ | 448/504 [20:40<02:23,  2.56s/it]Model is not converging.  Current: -817.020690953876 is not greater than -817.0205465953369. Delta is -0.00014435853915983898
#  89%|████████▉ | 449/504 [20:44<02:30,  2.74s/it]Model is not converging.  Current: -1085.8693733278092 is not greater than -1085.8653153650987. Delta is -0.004057962710476204
#  89%|████████▉ | 450/504 [20:47<02:36,  2.90s/it]Model is not converging.  Current: -1167.0247926815348 is not greater than -1167.0240080376213. Delta is -0.0007846439134482353
#  89%|████████▉ | 451/504 [20:50<02:32,  2.88s/it]Model is not converging.  Current: -1050.7788543573881 is not greater than -1050.7787302451218. Delta is -0.0001241122663486749
#  90%|████████▉ | 453/504 [20:55<02:19,  2.74s/it]Model is not converging.  Current: -988.2528378214299 is not greater than -988.2528041068274. Delta is -3.3714602523104986e-05
#  90%|█████████ | 456/504 [21:04<02:21,  2.95s/it]Model is not converging.  Current: -686.0079524191689 is not greater than -686.0079514114084. Delta is -1.0077604883917957e-06
# Model is not converging.  Current: -1043.5602681450846 is not greater than -1043.560252448344. Delta is -1.5696740547355148e-05
#  91%|█████████ | 457/504 [21:06<02:12,  2.82s/it]Model is not converging.  Current: -1219.0902086524711 is not greater than -1219.0899979707235. Delta is -0.00021068174760330294
# Model is not converging.  Current: -803.0156634931607 is not greater than -803.0152355290767. Delta is -0.0004279640839968124
#  91%|█████████ | 458/504 [21:09<02:08,  2.79s/it]Model is not converging.  Current: -998.4835819696511 is not greater than -998.4835551653648. Delta is -2.6804286335391225e-05
#  91%|█████████ | 459/504 [21:11<01:59,  2.65s/it]Model is not converging.  Current: -859.1205543602097 is not greater than -859.1205190528202. Delta is -3.530738945300982e-05
#  91%|█████████▏| 461/504 [21:19<02:17,  3.20s/it]Model is not converging.  Current: -1256.5951030521428 is not greater than -1256.5949818952445. Delta is -0.00012115689833080978
#  92%|█████████▏| 464/504 [21:27<01:54,  2.87s/it]Model is not converging.  Current: -881.4943464006501 is not greater than -881.4943159365054. Delta is -3.0464144742836652e-05
#  92%|█████████▏| 466/504 [21:34<01:58,  3.13s/it]Model is not converging.  Current: -838.0966869552535 is not greater than -838.0959954174859. Delta is -0.0006915377675795753
#  94%|█████████▎| 472/504 [21:51<01:27,  2.74s/it]Model is not converging.  Current: -889.608140847483 is not greater than -889.6081245573987. Delta is -1.6290084317915898e-05
#  94%|█████████▍| 474/504 [21:56<01:21,  2.73s/it]Model is not converging.  Current: -1019.9686594647427 is not greater than -1019.9686327978518. Delta is -2.666689090347063e-05
#  94%|█████████▍| 476/504 [22:01<01:06,  2.39s/it]Model is not converging.  Current: -781.1213047225248 is not greater than -781.1212856206871. Delta is -1.9101837665402854e-05
#  95%|█████████▍| 477/504 [22:04<01:10,  2.61s/it]Model is not converging.  Current: -1138.4208770385244 is not greater than -1138.420867835184. Delta is -9.203340368912905e-06
#  95%|█████████▍| 478/504 [22:07<01:16,  2.92s/it]Model is not converging.  Current: -982.4158353859013 is not greater than -982.4157852678883. Delta is -5.011801306409325e-05
# Model is not converging.  Current: -1185.9570186144385 is not greater than -1185.9535081946183. Delta is -0.003510419820258903
#  95%|█████████▌| 481/504 [22:17<01:16,  3.32s/it]Model is not converging.  Current: -1022.7861524739131 is not greater than -1022.786145894879. Delta is -6.5790341068350244e-06
# Model is not converging.  Current: -904.8235343339545 is not greater than -904.821070232269. Delta is -0.0024641016855184716
#  96%|█████████▌| 483/504 [22:24<01:09,  3.32s/it]Model is not converging.  Current: -958.8896387582423 is not greater than -958.8896212056014. Delta is -1.7552640883877757e-05
#  96%|█████████▌| 484/504 [22:28<01:07,  3.37s/it]Model is not converging.  Current: -1041.2635326374925 is not greater than -1041.2634317276604. Delta is -0.00010090983209920523
#  96%|█████████▋| 486/504 [22:34<00:57,  3.19s/it]Model is not converging.  Current: -754.5071119013323 is not greater than -754.5059674103094. Delta is -0.0011444910229556626
# Model is not converging.  Current: -798.7805887014332 is not greater than -798.7804463098906. Delta is -0.00014239154256756592
#  97%|█████████▋| 488/504 [22:42<00:59,  3.69s/it]Model is not converging.  Current: -932.2303103699521 is not greater than -932.230308964893. Delta is -1.4050591516934219e-06
# Model is not converging.  Current: -1113.5943913267504 is not greater than -1113.5943384989496. Delta is -5.2827800800514524e-05
#  97%|█████████▋| 489/504 [22:46<00:56,  3.77s/it]Model is not converging.  Current: -980.4984690574958 is not greater than -980.4983790399596. Delta is -9.001753619486408e-05
# Model is not converging.  Current: -1008.9329516264304 is not greater than -1008.9327406910506. Delta is -0.0002109353797550284
# Model is not converging.  Current: -933.6538507699913 is not greater than -933.6537066962331. Delta is -0.00014407375817881984
#  97%|█████████▋| 490/504 [22:49<00:48,  3.47s/it]Model is not converging.  Current: -1068.4778887896798 is not greater than -1068.4778816355404. Delta is -7.154139439080609e-06
#  97%|█████████▋| 491/504 [22:52<00:43,  3.35s/it]Model is not converging.  Current: -972.7814519650415 is not greater than -972.7812841146729. Delta is -0.0001678503685980104
#  98%|█████████▊| 492/504 [22:56<00:41,  3.47s/it]Model is not converging.  Current: -861.9766192422921 is not greater than -861.9756272632203. Delta is -0.0009919790718413424
# Model is not converging.  Current: -846.342288472145 is not greater than -846.3341561334477. Delta is -0.00813233869735086
# Model is not converging.  Current: -1265.486119919069 is not greater than -1265.4860544120497. Delta is -6.55070193715801e-05
#  98%|█████████▊| 494/504 [23:02<00:33,  3.35s/it]Model is not converging.  Current: -1162.6974531781516 is not greater than -1162.6974518980542. Delta is -1.2800974218407646e-06
#  98%|█████████▊| 496/504 [23:09<00:26,  3.34s/it]Model is not converging.  Current: -1075.5176954369606 is not greater than -1075.5176143615695. Delta is -8.107539110824291e-05
#  99%|█████████▉| 498/504 [23:17<00:21,  3.60s/it]Model is not converging.  Current: -1015.2786658749087 is not greater than -1015.278662522003. Delta is -3.352905764586467e-06
#  99%|█████████▉| 499/504 [23:19<00:16,  3.32s/it]Model is not converging.  Current: -1093.0673991553454 is not greater than -1093.0673671686252. Delta is -3.1986720159693505e-05
# 100%|██████████| 504/504 [23:41<00:00,  2.82s/it]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 130
#     128 results = walk_forward_regime_search_grouped(df)
#     129 summary = summarize_results(results)
# --> 130 generate_report(summary)
#     131 for (symbol, model) in results:
#     132     last = results[(symbol, model)][-1]
#
# Cell In[15], line 113, in generate_report(summary_df)
#     108 def generate_report(summary_df):
#     109     report_lines = [
#     110         "# 📈 Adaptive Market Regime Classification Report\n",
#     111         "\n",
#     112         "## Model Performance by Stock\n",
# --> 113         summary_df.to_markdown(index=False),
#     114         "\n",
#     115         "---\n",
#     116         "## Interpretation\n",
#     117         "- Higher silhouette score → better cluster separation.\n",
#     118         "- Monitor which model works best for each stock over time.\n",
#     119         "- Combine regime classification with strategy backtests.\n"
#     120     ]
#     121     with open("regime_classification_report.md", "w") as f:
#     122         f.write("\n".join(report_lines))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:2988, in DataFrame.to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2986 kwargs.setdefault("tablefmt", "pipe")
#    2987 kwargs.setdefault("showindex", index)
# -> 2988 tabulate = import_optional_dependency("tabulate")
#    2989 result = tabulate.tabulate(self, **kwargs)
#    2990 if buf is None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\compat\_optional.py:164, in import_optional_dependency(name, extra, errors, min_version)
#     162     return None
#     163 elif errors == "raise":
# --> 164     raise ImportError(msg)
#     165 else:
#     166     return None
#
# ImportError: Pandas requires version '0.9.0' or newer of 'tabulate' (version '0.8.10' currently installed).

# %%
def summarize_regimes_v2(df, results):
    rows = []
    for (symbol, model), runs in tqdm(results.items()):
        for run in runs:
            sub_df = compute_regime_features(df[df['symbol'] == symbol]).iloc[run['start']:run['end']].copy()
            sub_df['regime'] = run['labels']
            for regime in sorted(sub_df['regime'].unique()):
                regime_df = sub_df[sub_df['regime'] == regime]
                rows.append({
                    'symbol': symbol,
                    'model': model,
                    'regime': regime,
                    'mean_return': regime_df['return'].mean(),
                    'volatility': regime_df['return'].std(),
                    'frequency': len(regime_df)
                })
    summary_df = pd.DataFrame(rows)
    return summary_df.groupby(['symbol', 'model', 'regime']).agg(
        mean_return=('mean_return', 'mean'),
        volatility=('volatility', 'mean'),
        frequency=('frequency', 'sum')
    ).reset_index().sort_values(by='mean_return', ascending=False)

detailed_stats = summarize_regimes_v2(df, results)
print(detailed_stats.head())
# Out:
# 100%|██████████| 1512/1512 [42:59<00:00,  1.71s/it]
#      symbol   model  regime  mean_return  volatility  frequency
# 536    BIIB     hmm       2     0.112633    0.017837       1298
# 539    BIIB  kmeans       2     0.071240    0.015408       2168
# 533    BIIB     gmm       2     0.070695    0.016127       2244
# 2336   JNPR     hmm       2     0.053508    0.013800       1243
# 2333   JNPR     gmm       2     0.043821    0.014168       1914

# %%
# !pip install tabulate

# %%
detailed_stats['regime'].unique()
# Out:
# array([2, 0, 1], dtype=int64)
